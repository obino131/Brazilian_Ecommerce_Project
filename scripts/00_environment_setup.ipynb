# %% [markdown]
# SETUP CATALOG AND SCHEMA IN SQL

# %%
# %sql

CREATE CATALOG IF NOT EXISTS olist_project;

# %%
# %sql
USE CATALOG olist_project;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS olist_project.raw_data;
CREATE SCHEMA IF NOT EXISTS olist_project.bronze;
CREATE SCHEMA IF NOT EXISTS olist_project.silver;
CREATE SCHEMA IF NOT EXISTS olist_project.gold;

# %%
# %sql
SHOW DATABASES FROM olist_project;

# %% [markdown]
# SETUP CATALOG AND SCHEMA IN PYTHON
#
# professional standard

# %%
# Databricks notebook source

# 1. Create and set the Catalog
# Replace 'olist_project' with whatever you want your top-level folder to be called
catalog_name = "olist_project"
spark.sql(f"CREATE CATALOG IF NOT EXISTS {catalog_name}")
spark.sql(f"USE CATALOG {catalog_name}")

# 2. Initialize Schemas inside your new Catalog
spark.sql("CREATE SCHEMA IF NOT EXISTS bronze")
spark.sql("CREATE SCHEMA IF NOT EXISTS silver")
spark.sql("CREATE SCHEMA IF NOT EXISTS gold")

print(f"✅ Catalog '{catalog_name}' and Medallion schemas are ready.")
